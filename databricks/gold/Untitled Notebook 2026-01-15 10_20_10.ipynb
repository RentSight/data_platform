# %%
df_gold_more_expensive = spark.read.option("header", True).parquet("/Volumes/rentsight/airbnb-infos/02-silver/listings_silver_rj/part-00000-tid-8652196370360938618-cd6639da-8b83-46f6-b38c-01edbf9a188c-334-1.c000.snappy.parquet")
display(df_gold_more_expensive.describe())
# display(df_gold_more_expensive)

# %%
df_gold_more_expensive = df_gold_more_expensive.orderBy(df_gold_more_expensive.price.desc())
display(df_gold_more_expensive)

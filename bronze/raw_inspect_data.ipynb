# %%
df_listing_infos = spark.read \
                .option("header", True) \
                .option("inferSchema", True) \
                .csv("/Volumes/rentsight/airbnb-infos/01-raw/listings.csv")

# %%
display(df_listing_infos)

# %% [markdown]
# ## Ver schema

# %%
df_listing_infos_pd = df_listing_infos.toPandas()

display(df_listing_infos_pd.info())
